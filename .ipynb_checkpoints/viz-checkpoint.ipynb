# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# ====================================================== FUNC ======================================================
def show_plot(plots, _xlabel='x', _ylabel='y', _title='Graph', fname='graph'):
    fig, ax = plt.subplots()
    for product_name, points in plots.items():
        ax.plot(points.keys(), points.values(), label=product_name)
    
    ax.set(xlabel=_xlabel, ylabel=_ylabel, title=_title)
    ax.grid()
    ax.legend()
    
    fig.savefig(f'{fname}.png')
    plt.show()

# ====================================================== CONST ======================================================
month_names = {
    1: 'январь',
    2: 'февраль',
    3: 'март',
    4: 'апрель',
    5: 'май',
    6: 'июнь',
    7: 'июль',
    8: 'август',
    9: 'сентябрь',
    10: 'октябрь',
    11: 'ноябрь',
    12: 'декабрь'
}

# ====================================================== LOAD ======================================================
df = pd.read_excel('./Accenture_Датасет.xlsx')

df_products = df.filter(items=['Код товара', 'Наименование товара']).drop_duplicates()
df_dates = df.filter(items=['Месяц', 'Год']).drop_duplicates()
prices_avg = {}
volumes_sum = {}

for index, product in df_products.iterrows():
    product_id = product['Код товара']
    product_name = product['Наименование товара']
    prices_avg[product_name] = {}
    volumes_sum[product_name] = {}
    for index, date in df_dates.iterrows():
        month = date['Месяц']
        year = date['Год']
        date_str = dt.datetime(year, month, 1).strftime('%m.%Y')
        df_by_product_by_date = df[(df['Код товара'] == product_id) & (df['Год'] == year) & (df['Месяц'] == month)]
        price_avg = df_by_product_by_date['Сумма в ценах продажи'].mean()
        prices_avg[product_name][date_str] = price_avg
        volume_sum = df_by_product_by_date['Продажи в кг'].sum()
        volumes_sum[product_name][date_str] = volume_sum
#        print(f'Средняя сумма в ценах продажи товара {product_name} за {month_names[month]} {year} года: {price_avg}')
#        print(f'Суммарный объем продаж товара {product_name} за {month_names[month]} {year} года: {volume_sum}')
#print(prices_avg)
#print(volumes_sum)

# ====================================================== PLOT ======================================================
show_plot(prices_avg, 'Дата', 'Цена (руб.)', 'Средняя сумма в ценах продажи', 'средняя_цена')
show_plot(volumes_sum, 'Дата', 'Объем (кг)', 'Суммарный объем продаж', 'суммарный_объем')
